# %%
# loading data
import pandas as pd
df = pd.read_csv("../assets/data/data.csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import streamlit as st

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
mapping = {1 : "Diabetic", 0 : "Non-Diabetic"}
tmp = df.copy()
tmp["Outcome"] = tmp["Outcome"].map(mapping)

# %%
tmp.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age       Outcome
# 0                     0.627   50      Diabetic
# 1                     0.351   31  Non-Diabetic
# 2                     0.672   32      Diabetic
# 3                     0.167   21  Non-Diabetic
# 4                     2.288   33      Diabetic

# %%
tmp.Outcome.unique()
# Out:
# array(['Diabetic', 'Non-Diabetic'], dtype=object)

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 12))

sns.histplot(data=tmp, x="Pregnancies", hue="Outcome", multiple="dodge", kde=True, color="skyblue", ax=axs[0, 0])
sns.histplot(data=tmp, x="Glucose", hue="Outcome", multiple="dodge", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=tmp, x="BloodPressure", hue="Outcome", multiple="dodge", kde=True, color="gold", ax=axs[0, 2])
sns.histplot(data=tmp, x="SkinThickness", hue="Outcome", multiple="dodge", kde=True, color="teal", ax=axs[0, 3])
sns.histplot(data=tmp, x="Insulin", hue="Outcome", multiple="dodge", kde=True, color="skyblue", ax=axs[1, 0])
sns.histplot(data=tmp, x="BMI", hue="Outcome", multiple="dodge", kde=True, color="olive", ax=axs[1, 1])
sns.histplot(data=tmp, x="DiabetesPedigreeFunction", hue="Outcome", multiple="dodge", kde=True, color="gold", ax=axs[1, 2])
sns.histplot(data=tmp, x="Age", hue="Outcome", multiple="dodge", kde=True, color="teal", ax=axs[1, 3])

plt.show()

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 8))
sns.displot(tmp, x="BMI", hue="Outcome", multiple="dodge", element="step", ax=axes[0][0])
sns.displot(tmp, x="BMI", hue="Outcome", element="step", ax=axes[0][1])
plt.show()
# Out:
# /home/amirhessam/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /home/amirhessam/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for idx, col in enumerate(tmp.columns):
    ax = fig.add_subplot(2, 5, 1+idx)
    ax.displot(tmp, x=col, hue="Outcome", element="step")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-b6e1eeafd663> in <module>
#       3 for idx, col in enumerate(tmp.columns):
#       4     ax = fig.add_subplot(2, 5, 1+idx)
# ----> 5     ax.displot(tmp, x=col, hue="Outcome", element="step")
#       6 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'displot'

# %%
def plot_hist(df):
    mapping = {1 : "Diabetic", 0 : "Non-Diabetic"}
    tmp = df.copy()
    tmp["Outcome"] = tmp["Outcome"].map(mapping)
#     for col in df.columns:
#         if col not in ["Outcome"]:
#             sns.displot(tmp, x=col, hue="Outcome", multiple="dodge", element="step")
#             plt.show()

#     g = sns.PairGrid(df, hue="Outcome")
#     g.map_diag(sns.histplot)
#     g.map_offdiag(sns.scatterplot)
#     g.add_legend()

    sns.pairplot(tmp, hue="Outcome", height=2.5)
    plt.show()

# %%
"LogLoss".lower()
# Out:
# 'logloss'

# %%
sns.di

# %%
from slickml.optimization import XGBoostClassifierBayesianOpt

# %%
XGBoostClassifierBayesianOpt(n_splits=)
